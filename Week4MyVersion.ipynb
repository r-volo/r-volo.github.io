# %% [markdown]
# <a href="https://colab.research.google.com/github/r-volo/r-volo.github.io/blob/main/Week4MyVersion.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.read_csv('API_co2.csv',skiprows=4)

# %%
df
# Out:
#                     Country Name Country Code      Indicator Name  \
# 0                          Aruba          ABW  CO2 emissions (kt)
# 1    Africa Eastern and Southern          AFE  CO2 emissions (kt)
# 2                    Afghanistan          AFG  CO2 emissions (kt)
# 3     Africa Western and Central          AFW  CO2 emissions (kt)
# 4                         Angola          AGO  CO2 emissions (kt)
# ..                           ...          ...                 ...
# 261                       Kosovo          XKX  CO2 emissions (kt)
# 262                  Yemen, Rep.          YEM  CO2 emissions (kt)
# 263                 South Africa          ZAF  CO2 emissions (kt)
# 264                       Zambia          ZMB  CO2 emissions (kt)
# 265                     Zimbabwe          ZWE  CO2 emissions (kt)
#
#      Indicator Code          1990         1991         1992         1993  \
# 0    EN.ATM.CO2E.KT           NaN          NaN          NaN          NaN
# ...

# %%
df2 = df.drop(['Indicator Name','Indicator Code'], axis=1)

# %%
df2
# Out:
#                     Country Name Country Code          1990         1991  \
# 0                          Aruba          ABW           NaN          NaN
# 1    Africa Eastern and Southern          AFE  304354.88270  298735.4356
# 2                    Afghanistan          AFG    2380.00000    2230.0000
# 3     Africa Western and Central          AFW   97925.79689  111479.4705
# 4                         Angola          AGO    6560.00000    6670.0000
# ..                           ...          ...           ...          ...
# 261                       Kosovo          XKX           NaN          NaN
# 262                  Yemen, Rep.          YEM    6640.00000    8500.0000
# 263                 South Africa          ZAF  247660.00000  242330.0000
# 264                       Zambia          ZMB    2740.00000    2880.0000
# 265                     Zimbabwe          ZWE   16540.00000   18300.0000
#
#             1992         1993        1994         1995         1996  \
# ...

# %%
df3 = df2.set_index(['Country Name', 'Country Code']).stack().reset_index()

# %%
df3
# Out:
#                      Country Name Country Code level_2             0
# 0     Africa Eastern and Southern          AFE    1990  304354.88270
# 1     Africa Eastern and Southern          AFE    1991  298735.43560
# 2     Africa Eastern and Southern          AFE    1992  295090.00000
# 3     Africa Eastern and Southern          AFE    1993  303600.00000
# 4     Africa Eastern and Southern          AFE    1994  312160.00000
# ...                           ...          ...     ...           ...
# 7142                     Zimbabwe          ZWE    2015   12430.00031
# 7143                     Zimbabwe          ZWE    2016   11020.00046
# 7144                     Zimbabwe          ZWE    2017   10340.00015
# 7145                     Zimbabwe          ZWE    2018   12380.00011
# 7146                     Zimbabwe          ZWE    2019   11760.00023
#
# [7147 rows x 4 columns]

# %%
df4 = df3.rename(columns={'level_2':'Year', 0:'CO2 Emmisions (Kt)'})

# %%
df4
# Out:
#                      Country Name Country Code  Year  CO2 Emmisions (Kt)
# 0     Africa Eastern and Southern          AFE  1990        304354.88270
# 1     Africa Eastern and Southern          AFE  1991        298735.43560
# 2     Africa Eastern and Southern          AFE  1992        295090.00000
# 3     Africa Eastern and Southern          AFE  1993        303600.00000
# 4     Africa Eastern and Southern          AFE  1994        312160.00000
# ...                           ...          ...   ...                 ...
# 7142                     Zimbabwe          ZWE  2015         12430.00031
# 7143                     Zimbabwe          ZWE  2016         11020.00046
# 7144                     Zimbabwe          ZWE  2017         10340.00015
# 7145                     Zimbabwe          ZWE  2018         12380.00011
# 7146                     Zimbabwe          ZWE  2019         11760.00023
#
# [7147 rows x 4 columns]

# %%
df4.set_index('Country Name').to_csv('exportedCollab.csv')
